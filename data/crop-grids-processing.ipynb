# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import xarray as xr

# %%
path = "./unsynced-data/crop-grid/CROPGRIDSv1.06_NC_maps/"
filename = "CROPGRIDSv1.06_cowpea.nc"
cowpea = xr.open_dataset(path+filename)

# %%
cowpea.lon
# Out:
# <xarray.DataArray 'lon' (lon: 7200)>
# array([-179.975, -179.925, -179.875, ...,  179.875,  179.925,  179.975],
#       dtype=float32)
# Coordinates:
#   * lon      (lon) float32 -180.0 -179.9 -179.9 -179.8 ... 179.9 179.9 180.0
# Attributes:
#     standard_name:  longitude
#     long name:      longitude
#     units:          degrees_east
#     axis:           X

# %%
cowpea_gdf = gpd.GeoDataFrame(cowpea, geometry=gpd.points_from_xy(cowpea.lon, cowpea.lat))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/camkruse/projects/earthgenome/vacs-map/data/crop-grids-processing.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/camkruse/projects/earthgenome/vacs-map/data/crop-grids-processing.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> cowpea_gdf = gpd.GeoDataFrame(cowpea, geometry=gpd.points_from_xy(cowpea.lon, cowpea.lat))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/geo/lib/python3.10/site-packages/geopandas/array.py:261, in points_from_xy(x, y, z, crs)
#     218 def points_from_xy(x, y, z=None, crs=None):
#     219     """
#     220     Generate GeometryArray of shapely Point geometries from x, y(, z) coordinates.
#     221
#    (...)
#     259     output : GeometryArray
#     260     """
# --> 261     return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)
#
# ...
