# %%
import pandas as pd
import geopandas as gpd
import h3
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Point
from shapely.geometry import Polygon

# %%
def points_to_grid (points_gdf, edge_size):
    square_gdf = points_gdf.copy()
    for index, row in square_gdf.iterrows():
        point = row['geometry']
        
        # Define the coordinates for the corners of the square
        x, y = point.x, point.y
        square_half_size = edge_size*0.5
        
        # Create the coordinates for the square's corners
        square_coords = [(x - square_half_size, y - square_half_size),
                        (x + square_half_size, y - square_half_size),
                        (x + square_half_size, y + square_half_size),
                        (x - square_half_size, y + square_half_size)]
        
        polygon = Polygon(square_coords)
        square_gdf.loc[index, 'geometry'] = polygon
    return square_gdf

# %%
cowpea = pd.read_csv('cowpea_gridcell_summary.csv')
cowpea_gdf = gpd.GeoDataFrame(cowpea, geometry=gpd.points_from_xy(cowpea.long, cowpea.lat))
cowpea_gdf.set_crs(epsg=4326, inplace=True)
cowpea_gdf
# Out:
#          exp  long    lat  baseline_yield  ssp126_gfdl_av  ssp370_gfdl_av
# 0     114115 -2.75  10.75            1885            1842            1411  \
# 1     114115 -2.75  10.75            1767            1979            1775
# 2     114115 -2.75  10.75            1742            1823            1870
# 3     114115 -2.75  10.75            1766            1870            1881
# 4     114115 -2.75  10.75            1834            1997            1902
# ...      ...   ...    ...             ...             ...             ...
# 1015  120601  0.25   6.25            1557             745            1626
# 1016  120601  0.25   6.25            1625            1690            1542
# 1017  120601  0.25   6.25            1486            1668            1641
# 1018  120601  0.25   6.25            1621            1760            1567
# 1019  120601  0.25   6.25            1728             818            1529
#
#       ssp126_ipsl_av  ssp370_ipsl_av  ssp126_gfdl_pc  ssp370_gfdl_pc
# 0               1943            1663           -2.28          -25.15  \
# 1               1701            1683           12.00            0.45
# 2               1767            1540            4.65            7.35
# 3               1381            1392            5.89            6.51
# 4               1588            1786            8.89            3.71
# ...              ...             ...             ...             ...
# 1015            1580            1141          -52.15            4.43
# 1016            1618            1341            4.00           -5.11
# 1017            1307            1032           12.25           10.43
# 1018            1513            1150            8.57           -3.33
# 1019            1694            1205          -52.66          -11.52
#
#       ssp126_ipsl_pc  ssp370_ipsl_pc                   geometry
# 0               3.08          -11.78  POINT (-2.75000 10.75000)
# 1              -3.74           -4.75  POINT (-2.75000 10.75000)
# 2               1.44          -11.60  POINT (-2.75000 10.75000)
# 3             -21.80          -21.18  POINT (-2.75000 10.75000)
# 4             -13.41           -2.62  POINT (-2.75000 10.75000)
# ...              ...             ...                        ...
# 1015            1.48          -26.72    POINT (0.25000 6.25000)
# 1016           -0.43          -17.48    POINT (0.25000 6.25000)
# 1017          -12.05          -30.55    POINT (0.25000 6.25000)
# 1018           -6.66          -29.06    POINT (0.25000 6.25000)
# 1019           -1.97          -30.27    POINT (0.25000 6.25000)
#
# [1020 rows x 13 columns]

# %%
average_cowpea = cowpea.groupby('exp').mean()
average_cowpea["value_type"] = "mean"
average_cowpea = average_cowpea.reset_index()

max_cowpea = cowpea.groupby('exp').max()
max_cowpea["value_type"] = "max"
max_cowpea = max_cowpea.reset_index()

min_cowpea = cowpea.groupby('exp').min()
min_cowpea["value_type"] = "min"
min_cowpea = min_cowpea.reset_index()

cowpea_summary = pd.concat([average_cowpea, max_cowpea, min_cowpea])

cowpea_summary_gdf_point = gpd.GeoDataFrame(cowpea_summary, geometry=gpd.points_from_xy(cowpea_summary.long, cowpea_summary.lat))
cowpea_summary_gdf_point.set_crs(epsg=4326, inplace=True)
# Out:
#        exp  long    lat  baseline_yield  ssp126_gfdl_av  ssp370_gfdl_av
# 0   114115 -2.75  10.75         1770.00         1858.80         1756.05  \
# 1   114116 -2.25  10.75         1762.95         1845.15         1771.40
# 2   114117 -1.75  10.75         1719.05         1767.20         1689.50
# 3   114118 -1.25  10.75         1686.70         1685.60         1558.60
# 4   114119 -0.75  10.75         1693.70         1709.60         1619.15
# ..     ...   ...    ...             ...             ...             ...
# 46  119880 -0.25   6.75         1532.00          778.00         1320.00
# 47  119881  0.25   6.75         1608.00         1040.00         1543.00
# 48  120599 -0.75   6.25         1408.00          932.00         1265.00
# 49  120600 -0.25   6.25         1569.00         1253.00         1578.00
# 50  120601  0.25   6.25         1486.00          745.00         1335.00
#
#     ssp126_ipsl_av  ssp370_ipsl_av  ssp126_gfdl_pc  ssp370_gfdl_pc
# 0          1614.65         1386.50           5.125         -0.6590  \
# 1          1638.95         1419.50           4.762          0.5400
# 2          1520.05         1285.55           2.971         -1.5430
# 3          1422.35         1156.70           0.077         -7.2415
# 4          1450.35         1189.20           1.090         -4.0335
# ..             ...             ...             ...             ...
# 46         1086.00          855.00         -50.730        -19.1700
# 47         1216.00         1008.00         -37.160         -6.9100
# 48         1061.00          985.00         -36.430        -15.6700
# 49         1358.00         1219.00         -22.700         -5.5000
# 50          982.00          858.00         -52.660        -17.5400
#
#     ssp126_ipsl_pc  ssp370_ipsl_pc value_type                   geometry
# 0          -8.7290        -21.6865       mean  POINT (-2.75000 10.75000)
# 1          -6.9335        -19.3730       mean  POINT (-2.25000 10.75000)
# 2         -11.5285        -25.1335       mean  POINT (-1.75000 10.75000)
# 3         -15.4780        -31.2530       mean  POINT (-1.25000 10.75000)
# 4         -14.2590        -29.6895       mean  POINT (-0.75000 10.75000)
# ..             ...             ...        ...                        ...
# 46        -37.0400        -47.3500        min   POINT (-0.25000 6.75000)
# 47        -28.8500        -37.3100        min    POINT (0.25000 6.75000)
# 48        -29.2700        -33.7600        min   POINT (-0.75000 6.25000)
# 49        -18.8300        -27.2300        min   POINT (-0.25000 6.25000)
# 50        -39.3500        -46.5100        min    POINT (0.25000 6.25000)
#
# [153 rows x 14 columns]

# %%
cowpea_summary_gdf_point
# Out:
#        exp  long    lat  baseline_yield  ssp126_gfdl_av  ssp370_gfdl_av
# 0   114115 -2.75  10.75         1770.00         1858.80         1756.05  \
# 1   114116 -2.25  10.75         1762.95         1845.15         1771.40
# 2   114117 -1.75  10.75         1719.05         1767.20         1689.50
# 3   114118 -1.25  10.75         1686.70         1685.60         1558.60
# 4   114119 -0.75  10.75         1693.70         1709.60         1619.15
# ..     ...   ...    ...             ...             ...             ...
# 46  119880 -0.25   6.75         1532.00          778.00         1320.00
# 47  119881  0.25   6.75         1608.00         1040.00         1543.00
# 48  120599 -0.75   6.25         1408.00          932.00         1265.00
# 49  120600 -0.25   6.25         1569.00         1253.00         1578.00
# 50  120601  0.25   6.25         1486.00          745.00         1335.00
#
#     ssp126_ipsl_av  ssp370_ipsl_av  ssp126_gfdl_pc  ssp370_gfdl_pc
# 0          1614.65         1386.50           5.125         -0.6590  \
# 1          1638.95         1419.50           4.762          0.5400
# 2          1520.05         1285.55           2.971         -1.5430
# 3          1422.35         1156.70           0.077         -7.2415
# 4          1450.35         1189.20           1.090         -4.0335
# ..             ...             ...             ...             ...
# 46         1086.00          855.00         -50.730        -19.1700
# 47         1216.00         1008.00         -37.160         -6.9100
# 48         1061.00          985.00         -36.430        -15.6700
# 49         1358.00         1219.00         -22.700         -5.5000
# 50          982.00          858.00         -52.660        -17.5400
#
#     ssp126_ipsl_pc  ssp370_ipsl_pc value_type                   geometry
# 0          -8.7290        -21.6865       mean  POINT (-2.75000 10.75000)
# 1          -6.9335        -19.3730       mean  POINT (-2.25000 10.75000)
# 2         -11.5285        -25.1335       mean  POINT (-1.75000 10.75000)
# 3         -15.4780        -31.2530       mean  POINT (-1.25000 10.75000)
# 4         -14.2590        -29.6895       mean  POINT (-0.75000 10.75000)
# ..             ...             ...        ...                        ...
# 46        -37.0400        -47.3500        min   POINT (-0.25000 6.75000)
# 47        -28.8500        -37.3100        min    POINT (0.25000 6.75000)
# 48        -29.2700        -33.7600        min   POINT (-0.75000 6.25000)
# 49        -18.8300        -27.2300        min   POINT (-0.25000 6.25000)
# 50        -39.3500        -46.5100        min    POINT (0.25000 6.25000)
#
# [153 rows x 14 columns]

# %%
cowpea_summary_gdf_poly = points_to_grid (cowpea_summary_gdf_point, 0.5)
cowpea_summary_gdf = pd.concat([cowpea_summary_gdf_point, cowpea_summmary_gdf_poly])
cowpea_summary_gdf.to_file("cowpea_summary.geojson", driver='GeoJSON')

# %%
cowpea_summary_gdf.describe()
# Out:
#                  exp         long          lat  baseline_yield
# count    1173.000000  1173.000000  1173.000000     1173.000000  \
# mean   116984.098039    -1.142157     8.759804     1576.905286
# std      2040.082622     0.920291     1.416516      183.737788
# min    114115.000000    -2.750000     6.250000      665.000000
# 25%    114841.000000    -1.750000     7.250000     1523.000000
# 50%    116996.000000    -1.250000     8.750000     1604.000000
# 75%    119156.000000    -0.250000    10.250000     1681.000000
# max    120601.000000     0.250000    10.750000     1971.000000
#
#        ssp126_gfdl_av  ssp370_gfdl_av  ssp126_ipsl_av  ssp370_ipsl_av
# count     1173.000000     1173.000000     1173.000000     1173.000000  \
# mean      1530.414706     1515.327536     1437.721398     1180.646249
# std        342.316945      312.434419      277.695549      396.798975
# min        282.000000      250.000000      328.000000      113.000000
# 25%       1504.000000     1458.000000     1331.000000      971.000000
# 50%       1644.000000     1606.000000     1507.000000     1320.000000
# 75%       1725.000000     1702.000000     1620.000000     1470.000000
# max       2051.000000     1977.000000     1943.000000     1786.000000
#
#        ssp126_gfdl_pc  ssp370_gfdl_pc  ssp126_ipsl_pc  ssp370_ipsl_pc
# count     1173.000000     1173.000000     1173.000000     1173.000000
# mean        -2.889749       -4.010267       -8.459831      -25.384838
# std         21.255480       17.883103       17.848989       24.216443
# min        -69.580000      -79.690000      -71.380000      -92.100000
# 25%         -7.610000       -7.090000      -15.490000      -37.470000
# 50%          1.510000        0.000000       -5.610000      -18.590000
# 75%          6.580000        4.790000        0.180000       -9.120000
# max        133.980000       64.440000       80.920000       64.430000

# %%
cowpea_summary_gdf
# Out:
#          exp  long    lat  baseline_yield  ssp126_gfdl_av  ssp370_gfdl_av
# 0     114115 -2.75  10.75         1770.00         1858.80         1756.05  \
# 1     114116 -2.25  10.75         1762.95         1845.15         1771.40
# 2     114117 -1.75  10.75         1719.05         1767.20         1689.50
# 3     114118 -1.25  10.75         1686.70         1685.60         1558.60
# 4     114119 -0.75  10.75         1693.70         1709.60         1619.15
# ...      ...   ...    ...             ...             ...             ...
# 1015  120601  0.25   6.25         1557.00          745.00         1626.00
# 1016  120601  0.25   6.25         1625.00         1690.00         1542.00
# 1017  120601  0.25   6.25         1486.00         1668.00         1641.00
# 1018  120601  0.25   6.25         1621.00         1760.00         1567.00
# 1019  120601  0.25   6.25         1728.00          818.00         1529.00
#
#       ssp126_ipsl_av  ssp370_ipsl_av  ssp126_gfdl_pc  ssp370_gfdl_pc
# 0            1614.65         1386.50           5.125         -0.6590  \
# 1            1638.95         1419.50           4.762          0.5400
# 2            1520.05         1285.55           2.971         -1.5430
# 3            1422.35         1156.70           0.077         -7.2415
# 4            1450.35         1189.20           1.090         -4.0335
# ...              ...             ...             ...             ...
# 1015         1580.00         1141.00         -52.150          4.4300
# 1016         1618.00         1341.00           4.000         -5.1100
# 1017         1307.00         1032.00          12.250         10.4300
# 1018         1513.00         1150.00           8.570         -3.3300
# 1019         1694.00         1205.00         -52.660        -11.5200
#
#       ssp126_ipsl_pc  ssp370_ipsl_pc value_type
# 0            -8.7290        -21.6865       mean  \
# 1            -6.9335        -19.3730       mean
# 2           -11.5285        -25.1335       mean
# 3           -15.4780        -31.2530       mean
# 4           -14.2590        -29.6895       mean
# ...              ...             ...        ...
# 1015          1.4800        -26.7200        NaN
# 1016         -0.4300        -17.4800        NaN
# 1017        -12.0500        -30.5500        NaN
# 1018         -6.6600        -29.0600        NaN
# 1019         -1.9700        -30.2700        NaN
#
#                                                geometry
# 0                             POINT (-2.75000 10.75000)
# 1                             POINT (-2.25000 10.75000)
# 2                             POINT (-1.75000 10.75000)
# 3                             POINT (-1.25000 10.75000)
# 4                             POINT (-0.75000 10.75000)
# ...                                                 ...
# 1015  POLYGON ((0.00000 6.00000, 0.50000 6.00000, 0....
# 1016  POLYGON ((0.00000 6.00000, 0.50000 6.00000, 0....
# 1017  POLYGON ((0.00000 6.00000, 0.50000 6.00000, 0....
# 1018  POLYGON ((0.00000 6.00000, 0.50000 6.00000, 0....
# 1019  POLYGON ((0.00000 6.00000, 0.50000 6.00000, 0....
#
# [1173 rows x 14 columns]

# %% [markdown]
# # Past work below

# %%
def points_to_grid (points_gdf, edge_size):
    square_gdf = points_gdf.copy()
    for index, row in square_gdf.iterrows():
        point = row['geometry']
        
        # Define the coordinates for the corners of the square
        x, y = point.x, point.y
        square_half_size = edge_size*0.5
        
        # Create the coordinates for the square's corners
        square_coords = [(x - square_half_size, y - square_half_size),
                        (x + square_half_size, y - square_half_size),
                        (x + square_half_size, y + square_half_size),
                        (x - square_half_size, y + square_half_size)]
        
        polygon = Polygon(square_coords)
        square_gdf.loc[index, 'geometry'] = polygon
    return square_gdf

# %%
# write tester to geojson
tester.to_file("cowpea_gridcell_summary_poly.geojson", driver='GeoJSON')

# %%
polygons = []
attributes = []

# Iterate through each point in the original GeoDataFrame
for index, row in tester.iterrows():
    point = row['geometry']  # Get the point geometry
    
    # Define the coordinates for the corners of the square
    x, y = point.x, point.y
    square_half_size = 0.25  # Half of 0.25 degrees
    
    # Create the coordinates for the square's corners
    square_coords = [(x - square_half_size, y - square_half_size),
                     (x + square_half_size, y - square_half_size),
                     (x + square_half_size, y + square_half_size),
                     (x - square_half_size, y + square_half_size)]
    
    # Create a Polygon geometry from the coordinates
    polygon = Polygon(square_coords)
    polygons.append(polygon)

# Create a new GeoDataFrame with the polygons
squares_gdf = gpd.GeoDataFrame(geometry=polygons, crs=tester.crs)
# replace tester geometry with squares_gdf geometry
tester['geometry'] = squares_gdf['geometry']

# %%
squares_gdf
# Out:
#         long    lat  baseline_yield  ssp126_gfdl_av  ssp370_gfdl_av
# exp
# 114115 -2.75  10.75         1770.00         1858.80         1756.05  \
# 114116 -2.25  10.75         1762.95         1845.15         1771.40
# 114117 -1.75  10.75         1719.05         1767.20         1689.50
# 114118 -1.25  10.75         1686.70         1685.60         1558.60
# 114119 -0.75  10.75         1693.70         1709.60         1619.15
# 114120 -0.25  10.75         1696.80         1708.70         1623.95
# 114835 -2.75  10.25         1751.15         1822.45         1745.65
# 114836 -2.25  10.25         1738.20         1825.70         1785.20
# 114837 -1.75  10.25         1711.45         1773.90         1704.90
# 114838 -1.25  10.25         1647.00         1685.30         1605.70
# 114839 -0.75  10.25         1646.10         1696.50         1624.25
# 114840 -0.25  10.25         1676.30         1708.10         1644.05
# 114841  0.25  10.25         1606.00         1653.30         1597.20
# 115555 -2.75   9.75         1680.10         1745.70         1719.15
# 115557 -1.75   9.75         1691.15         1753.00         1744.85
# 115558 -1.25   9.75         1616.55         1685.65         1653.10
# 115559 -0.75   9.75         1630.30         1679.10         1665.70
# 115560 -0.25   9.75         1653.25         1712.10         1717.15
# 115561  0.25   9.75         1601.00         1640.55         1651.60
# 116276 -2.25   9.25         1579.80         1708.20         1621.95
# 116277 -1.75   9.25         1591.05         1712.85         1659.40
# 116278 -1.25   9.25         1608.90         1711.80         1686.40
# 116279 -0.75   9.25         1618.45         1678.10         1668.75
# 116280 -0.25   9.25         1601.15         1650.70         1647.75
# 116281  0.25   9.25         1576.05         1610.70         1624.80
# 116996 -2.25   8.75         1603.95         1662.80         1642.15
# 116998 -1.25   8.75         1564.25         1651.95         1641.85
# 116999 -0.75   8.75         1556.55         1616.30         1621.40
# 117000 -0.25   8.75         1538.85         1585.40         1592.70
# 117001  0.25   8.75         1515.40         1544.75         1555.80
# 117716 -2.25   8.25         1222.70          774.60          618.55
# 117717 -1.75   8.25         1456.25         1611.95         1565.85
# 117718 -1.25   8.25         1527.30         1631.85         1608.15
# 117721  0.25   8.25         1513.65         1564.35         1557.80
# 118435 -2.75   7.75         1465.35         1117.00         1122.80
# 118436 -2.25   7.75         1451.10         1028.30         1067.15
# 118437 -1.75   7.75         1510.60         1162.35         1206.50
# 118438 -1.25   7.75         1165.00          703.55          740.90
# 119156 -2.25   7.25         1557.90         1333.70         1368.30
# 119157 -1.75   7.25         1576.30         1286.00         1307.70
# 119158 -1.25   7.25         1421.05          972.50         1018.90
# 119159 -0.75   7.25         1240.30          850.90          869.70
# 119160 -0.25   7.25         1264.75          909.05          932.75
# 119877 -1.75   6.75         1528.05         1391.75         1459.50
# 119878 -1.25   6.75         1558.15         1444.55         1513.40
# 119879 -0.75   6.75         1551.90         1405.40         1515.40
# 119880 -0.25   6.75         1666.10         1479.70         1641.95
# 119881  0.25   6.75         1677.95         1642.85         1678.40
# 120599 -0.75   6.25         1506.70         1422.70         1475.75
# 120600 -0.25   6.25         1656.45         1648.20         1645.85
# 120601  0.25   6.25         1621.20         1516.25         1581.80
#
#         ssp126_ipsl_av  ssp370_ipsl_av  ssp126_gfdl_pc  ssp370_gfdl_pc
# exp
# 114115         1614.65         1386.50          5.1250         -0.6590  \
# 114116         1638.95         1419.50          4.7620          0.5400
# 114117         1520.05         1285.55          2.9710         -1.5430
# 114118         1422.35         1156.70          0.0770         -7.2415
# 114119         1450.35         1189.20          1.0900         -4.0335
# 114120         1464.20         1222.30          0.8500         -4.0005
# 114835         1610.60         1397.60          4.3245         -0.0975
# 114836         1646.45         1446.90          5.1835          2.7500
# 114837         1551.30         1328.65          3.8235         -0.3015
# 114838         1434.85         1165.10          2.5015         -2.3140
# 114839         1449.90         1191.30          3.2560         -1.1985
# 114840         1473.65         1241.60          2.0495         -1.7720
# 114841         1410.35         1199.90          3.0490         -0.4725
# 115555         1599.80         1428.80          4.1160          2.3955
# 115557         1607.65         1410.00          3.7735          3.1955
# 115558         1505.10         1257.60          4.5810          2.6135
# 115559         1521.90         1313.20          3.1660          2.3175
# 115560         1574.00         1412.10          3.7395          3.9320
# 115561         1504.30         1316.20          2.5925          3.2065
# 116276         1581.55         1429.55          9.8515          4.2855
# 116277         1566.15         1343.30          8.8935          5.1445
# 116278         1549.70         1319.85          6.9450          5.2290
# 116279         1534.75         1357.40          3.8375          3.1845
# 116280         1527.55         1367.20          3.2675          2.9950
# 116281         1501.60         1323.35          2.3820          3.2095
# 116996         1556.55         1412.20          3.7800          2.3730
# 116998         1512.50         1333.10          7.2100          6.3835
# 116999         1504.95         1318.70          4.2435          4.5180
# 117000         1486.15         1320.45          3.2600          3.5900
# 117001         1442.65         1263.25          2.1075          2.7850
# 117716          795.10          350.95        -32.0215        -48.2680
# 117717         1507.25         1368.15         14.1760         10.0950
# 117718         1519.60         1373.60          8.2445          6.4685
# 117721         1475.80         1354.15          3.5350          3.1040
# 118435         1305.75          790.45        -23.6815        -22.9115
# 118436         1253.00          756.80        -27.6550        -25.8275
# 118437         1316.95          849.45        -21.2675        -19.4040
# 118438          910.25          500.40        -37.6590        -34.5325
# 119156         1398.15         1172.30        -14.2825        -12.0250
# 119157         1385.60          904.40        -18.5170        -16.6160
# 119158         1167.85          672.95        -31.4920        -27.7215
# 119159          977.95          534.35        -30.5165        -27.7595
# 119160          992.00          548.40        -27.7565        -23.2785
# 119877         1387.10         1180.90         -8.8670         -4.3170
# 119878         1425.70         1268.40         -7.3020         -2.7650
# 119879         1407.00         1198.70         -9.4465         -2.1475
# 119880         1511.20         1201.30        -11.1710         -1.2800
# 119881         1558.30         1327.50         -2.0095          0.0820
# 120599         1394.20         1272.60         -5.6140         -1.9215
# 120600         1584.85         1503.65         -0.3830         -0.5470
# 120601         1469.10         1250.60         -6.3185         -2.3255
#
#         ssp126_ipsl_pc  ssp370_ipsl_pc geometry
# exp
# 114115         -8.7290        -21.6865     None
# 114116         -6.9335        -19.3730     None
# 114117        -11.5285        -25.1335     None
# 114118        -15.4780        -31.2530     None
# 114119        -14.2590        -29.6895     None
# 114120        -13.6920        -27.8520     None
# 114835         -7.9195        -20.0025     None
# 114836         -5.1825        -16.6935     None
# 114837         -9.2885        -22.3160     None
# 114838        -12.7370        -29.1340     None
# 114839        -11.7535        -27.5180     None
# 114840        -11.9460        -25.8610     None
# 114841        -12.1135        -25.0855     None
# 115555         -4.6255        -14.8035     None
# 115557         -4.8105        -16.5270     None
# 115558         -6.3955        -21.8470     None
# 115559         -6.3515        -19.3075     None
# 115560         -4.6295        -14.4740     None
# 115561         -5.9305        -17.7665     None
# 116276          1.4815         -8.3575     None
# 116277         -0.4290        -14.8005     None
# 116278         -3.0670        -17.6785     None
# 116279         -5.0000        -16.0505     None
# 116280         -4.4740        -14.4225     None
# 116281         -4.5760        -15.8330     None
# 116996         -2.9065        -11.9180     None
# 116998         -1.6940        -13.6855     None
# 116999         -2.8880        -14.9310     None
# 117000         -3.2975        -14.0005     None
# 117001         -4.6955        -16.3955     None
# 117716        -32.7730        -69.8000     None
# 117717          6.8775         -2.7090     None
# 117718          0.9050         -8.8835     None
# 117721         -2.3395        -10.3845     None
# 118435        -10.6360        -45.8440     None
# 118436        -12.9360        -47.2440     None
# 118437        -12.3675        -43.7400     None
# 118438        -19.1560        -56.0920     None
# 119156        -10.1200        -24.6435     None
# 119157        -11.9290        -42.8490     None
# 119158        -17.5840        -52.8275     None
# 119159        -19.8145        -56.4885     None
# 119160        -19.2330        -56.0030     None
# 119877         -9.0770        -22.5940     None
# 119878         -8.4315        -18.4730     None
# 119879         -9.2280        -22.5040     None
# 119880         -9.2085        -27.7815     None
# 119881         -7.1095        -20.8810     None
# 120599         -7.3865        -15.4125     None
# 120600         -4.2545         -9.0440     None
# 120601         -9.4110        -22.9205     None

# %%
print("Max: ", cowpea['lat'].max())
print("Min: ", cowpea['lat'].min())
print("Max: ", cowpea['long'].max())
print("Min: ", cowpea['long'].min())
# Out:
# Max:  10.75
# Min:  6.25
# Max:  0.25
# Min:  -2.75

# %%
# for reference
lat, lng = 37.769377, -122.388903
resolution = 9
h3.latlng_to_cell(lat, lng, resolution)
